# %%
import csv
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_train = pd.read_csv("Train_rev1.csv", usecols = ['Id','Title','LocationRaw','LocationNormalized',
                'ContractType','ContractTime','Company','Category',
                'SalaryRaw','SalaryNormalized','SourceName'])
df_train.head(10)
# Out:
#          Id                                              Title  \
# 0  12612628                        Engineering Systems Analyst
# 1  12612830                            Stress Engineer Glasgow
# 2  12612844                   Modelling and simulation analyst
# 3  12613049  Engineering Systems Analyst / Mathematical Mod...
# 4  12613647         Pioneer, Miser Engineering Systems Analyst
# 5  13179816         Engineering Systems Analyst Water Industry
# 6  14131336          Senior Subsea Pipeline Integrity Engineer
# 7  14663196  RECRUITMENT CONSULTANT  INDUSTRIAL / COMMERCIA...
# 8  14663197  RECRUITMENT CONSULTANT  CONSTRUCTION / TECHNIC...
# 9  15395797                             Subsea Cables Engineer
#
#                          LocationRaw LocationNormalized ContractType  \
# 0            Dorking, Surrey, Surrey            Dorking          NaN
# 1        Glasgow, Scotland, Scotland            Glasgow          NaN
# ...

# %%
df_category = df_train[['Category']].value_counts()
df_category.dropna()
df_category
# Out:
# Category
# IT Jobs                             38483
# Engineering Jobs                    25174
# Accounting & Finance Jobs           21846
# Healthcare & Nursing Jobs           21076
# Sales Jobs                          17272
# Other/General Jobs                  17055
# Teaching Jobs                       12637
# Hospitality & Catering Jobs         11351
# PR, Advertising & Marketing Jobs     8854
# Trade & Construction Jobs            8837
# HR & Recruitment Jobs                7713
# Admin Jobs                           7614
# Retail Jobs                          6584
# Customer Services Jobs               6063
# Legal Jobs                           3939
# Manufacturing Jobs                   3765
# Logistics & Warehouse Jobs           3633
# Social work Jobs                     3455
# Consultancy Jobs                     3263
# Travel Jobs                          3126
# Scientific & QA Jobs                 2489
# Charity & Voluntary Jobs             2332
# ...

# %%
# pie chart using pandas series plot()
df_train[['Category']].value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='None'>

# %%
# Create dataframe with job categories, level and normalized salary
# level: low average salary -> high average salary; sort rows and assign levels?

avg_df = pd.DataFrame(df_train[['Category', 'SalaryNormalized']])
avg_df = avg_df.groupby(['Category'])['SalaryNormalized'].mean().round(2)
avg_df
# Out:
# Category
# Accounting & Finance Jobs           38751.22
# Admin Jobs                          21053.66
# Charity & Voluntary Jobs            28272.92
# Consultancy Jobs                    37028.87
# Creative & Design Jobs              33173.54
# Customer Services Jobs              19861.44
# Domestic help & Cleaning Jobs       17553.62
# Energy, Oil & Gas Jobs              45653.09
# Engineering Jobs                    35838.27
# Graduate Jobs                       28107.51
# HR & Recruitment Jobs               32589.86
# Healthcare & Nursing Jobs           32589.24
# Hospitality & Catering Jobs         23702.74
# IT Jobs                             43983.91
# Legal Jobs                          42649.00
# Logistics & Warehouse Jobs          26497.80
# Maintenance Jobs                    17726.06
# Manufacturing Jobs                  26497.90
# Other/General Jobs                  35346.43
# PR, Advertising & Marketing Jobs    35593.79
# Part time Jobs                      10030.07
# ...

# %%
# useful features: 
# SalaryNormalized
# ContractType and ContractTime
# scale of level of position(analyst, junior, senior, manager, ceo etc.) concerns; hard to extract?
# scale of level of sector/category: making less money -> making more money (IT, Healthcare, hospitality, teaching etc.)
# jobs available per category? (1000 jobs in IT, 200 jobs in HR, 400 jobs in maintenance) -> where are people needed and does this affect their salary?

# %%
#Implementation of SVR
